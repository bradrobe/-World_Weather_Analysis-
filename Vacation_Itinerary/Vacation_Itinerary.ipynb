# %% [markdown]
# ## Deliverable 3. Create a Travel Itinerary Map.

# %%
# Dependencies and Setup
import pandas as pd
import requests
import gmaps

# Import API key
from config import g_key

# Configure gmaps
gmaps.configure(api_key=g_key)

# %%
# 1. Read the WeatherPy_vacation.csv into a DataFrame.
vacation_df = pd.read_csv("WeatherPy_vacation.csv")
vacation_df.head(20)
# Out:
#     City_ID             City Country  Max Temp Current Description      Lat  \
# 0         8          Rikitea      PF     79.00    scattered clouds -23.1203
# 1         9     Puerto Ayora      EC     73.54          few clouds  -0.7393
# 2        10           Atuona      PF     78.91          few clouds  -9.8000
# 3        11         Mbandaka      CD     73.38       broken clouds   0.0487
# 4        14   Puerto Penasco      MX     70.92           clear sky  31.3167
# 5        17            Vaini      TO     78.96          light rain -21.2000
# 6        19             Sibu      MY     77.31    scattered clouds   2.3000
# 7        21            Dubbo      AU     73.53     overcast clouds -32.2500
# 8        22          Kavieng      PG     83.79     overcast clouds  -2.5744
# 9        24             Hilo      US     75.25       broken clouds  19.7297
# 10       27             Sola      VU     82.83       moderate rain -13.8833
# 11       29          Ahipara      NZ     75.25     overcast clouds -35.1667
# 12       32  Charters Towers      AU     81.57     overcast clouds -20.1000
# 13       34  Arraial Do Cabo      BR     76.14           clear sky -22.9661
# 14       35          Camocim      BR     78.73           clear sky  -2.9022
# 15       37          Mareeba      AU     80.44    scattered clouds -17.0000
# 16       40            Feijo      BR     72.30     overcast clouds  -8.1642
# 17       51         Monrovia      LR     79.86     overcast clouds   6.3005
# 18       56          Vaitape      PF     81.32          light rain -16.5167
# 19       59       Butaritari      KI     82.58          light rain   3.0707
#
#          Lng                       Hotel Name
# 0  -134.9692                  People ThankYou
# 1   -90.3518        Finch Bay Galapagos Hotel
# 2  -139.0333                      Villa Enata
# 3    18.2603             Guest House Epervier
# 4  -113.5333              Playa Bonita Resort
# 5  -175.2000              Keleti Beach Resort
# 6   111.8167                RH HOTEL (4 Star)
# 7   148.6167  Quality Inn Dubbo International
# 8   150.7967              Nusa Island Retreat
# 9  -155.0900              Hilo Hawaiian Hotel
# 10  167.5500               Leumerus Bungalows
# 11  173.1667             Ahipara Holiday Park
# 12  146.2667       Cattleman's Rest Motor Inn
# 13  -42.0278              Pousada Porto Praia
# 14  -40.8411                 Ilha Praia Hotel
# 15  145.4333      Trinity Plains Tourist Park
# 16  -70.3536         Hotel e Restaurante Aҫai
# 17  -10.7969                       Sunset Inn
# 18 -151.7500             Conrad Bora Bora Nui
# 19  172.7902               Isles Sunset Lodge

# %%
# 2. Using the template add the city name, the country code, the weather description and maximum temperature for the city.
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 3a. Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in vacation_df.iterrows()]

# 3b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = vacation_df[["Lat", "Lng"]]

# %%
# 4a. Add a marker layer for each city to the map.
locations = vacation_df[["Lat", "Lng"]]
max_temp = vacation_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 4b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# From the map above pick 4 cities and create a vacation itinerary route to travel between the four cities. 
# 5. Create DataFrames for each city by filtering the 'vacation_df' using the loc method. 
# Hint: The starting and ending city should be the same city.

vacation_start = vacation_df.loc[vacation_df["City"] == "Mina"]
vacation_end = vacation_df.loc[vacation_df["City"] == "Mina"]

# %%
# Set the cities to stop at
vacation_stop1 = vacation_df.loc[vacation_df["City"] == "Ixtapa"]
vacation_stop2 = vacation_df.loc[vacation_df["City"] == "Lazaro Cardenas"]
vacation_stop3 = vacation_df.loc[vacation_df["City"] == "Acapulco"]

# %%
# 6. Get the latitude-longitude pairs as tuples from each city DataFrame using the to_numpy function and list indexing.
start = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
end = vacation_start["Lat"].to_numpy()[0], vacation_start["Lng"].to_numpy()[0]
print(f'Start: {start}, End: {end}')
      
# Get the lat and lng for the stops
coords_stop1 = vacation_stop1["Lat"].to_numpy()[0], vacation_stop1["Lng"].to_numpy()[0]
coords_stop2 = vacation_stop2["Lat"].to_numpy()[0], vacation_stop2["Lng"].to_numpy()[0]
coords_stop3 = vacation_stop3["Lat"].to_numpy()[0], vacation_stop3["Lng"].to_numpy()[0]

print(f'Stop 1: {coords_stop1}, Stop 2: {coords_stop2}, Stop 3: {coords_stop3}')
# Out:
# Start: (26.0011, -100.5299), End: (26.0011, -100.5299)
# Stop 1: (20.7, -105.2), Stop 2: (17.9583, -102.2), Stop 3: (16.8634, -99.8901)

# %%
# 7. Create a direction layer map using the start and end latitude-longitude pairs,
# and stop1, stop2, and stop3 as the waypoints. The travel_mode should be "DRIVING", "BICYCLING", or "WALKING".


# Create Map with route
fig = gmaps.figure()
city_itinerary = gmaps.directions_layer(
        start, end, waypoints=[coords_stop1, coords_stop2, coords_stop3],
        travel_mode='DRIVING')


fig.add_layer(city_itinerary)
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))

# %%
# 8. To create a marker layer map between the four cities.
#  Combine the four city DataFrames into one DataFrame using the concat() function.
itinerary_df = pd.concat([vacation_df.loc[vacation_df["City"] == "Mina"],
                                              vacation_df.loc[vacation_df["City"] == "Ixtapa"],
                                              vacation_df.loc[vacation_df["City"] == "Lazaro Cardenas"],
                                              vacation_df.loc[vacation_df["City"] == "Acapulco"]], axis=0)

                        
itinerary_df
# Out:
#      City_ID             City Country  Max Temp Current Description      Lat  \
# 199      583             Mina      MX     70.50     overcast clouds  26.0011
# 161      467           Ixtapa      MX     73.22       broken clouds  20.7000
# 140      401  Lazaro Cardenas      MX     76.23          few clouds  17.9583
# 188      549         Acapulco      MX     82.22           clear sky  16.8634
#
#           Lng                 Hotel Name
# 199 -100.5299                   Mina ctl
# 161 -105.2000    Hotel Plaza Providencia
# 140 -102.2000             quinta antigua
# 188  -99.8901  HS Hotsson Smart Acapulco

# %%
# 9 Using the template add city name, the country code, the weather description and maximum temperature for the city. 
info_box_template = """
<dl>
<dt>City</dt><dd>{City}</dd>
<dt>Country</dt><dd>{Country}</dd>
<dt>Current Description</dt><dd>{Current Description}</dd>
<dt>Max Temp</dt><dd>{Max Temp} °F</dd>
</dl>
"""

# 10a Get the data from each row and add it to the formatting template and store the data in a list.
hotel_info = [info_box_template.format(**row) for index, row in itinerary_df.iterrows()]

# 10b. Get the latitude and longitude from each row and store in a new DataFrame.
locations = itinerary_df[["Lat", "Lng"]]

# %%
# 11a. Add a marker layer for each city to the map.
locations = itinerary_df[["Lat", "Lng"]]
max_temp = itinerary_df["Max Temp"]
fig = gmaps.figure(center=(30.0, 31.0), zoom_level=1.5)
heat_layer = gmaps.heatmap_layer(locations, weights=max_temp,dissipating=False,
             max_intensity=300, point_radius=4)
marker_layer = gmaps.marker_layer(locations, info_box_content=hotel_info)
fig.add_layer(heat_layer)
fig.add_layer(marker_layer)

# 11b. Display the figure
fig
# Out:
# Figure(layout=FigureLayout(height='420px'))
