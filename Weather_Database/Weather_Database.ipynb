# %%
# Import Dependencies.
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# %%
# Create a set of random latitude and longitude combinations.
lats = np.random.uniform(low=-90.000, high=90.000, size=2000)
lngs = np.random.uniform(low=-180.000, high=180.000, size=2000)
lat_lngs = zip(lats, lngs)
lat_lngs

# %%
# Add the latitudes and longitudes to a list.
coordinates = list(lat_lngs)

# %%
# Use the citipy module to determine city based on latitude and longitude.
from citipy import citipy

# %%
# Create a list for holding the cities.
cities = []

for coordinate in coordinates:
    city = citipy.nearest_city(coordinate[0], coordinate[1]).city_name
    if city not in cities:
        cities.append(city)
len(cities)
# Out:
# 741

# %%
# Import the requests library.
import requests

# Import the API key.
from config import weather_api_key

# %%
# Starting URL for Weather Map API Call.
url = "http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=" + weather_api_key

# %%
# Import the time library and the datetime module from the datetime library 
import time
from datetime import datetime

# %%
# Create an empty list to hold the weather data.
city_data = []
# Print the beginning of the logging.
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters.
record_count = 1
set_count = 1

# Loop through all the cities in out list.
for i in range(len(cities)):
    
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count = 1
        record_count = 1
        time.sleep(60)
        
    # Create endpoint URL with each city.
    city_url = url + "&q=" + cities[i]
# Out:
# Beginning Data Retrieval
# -----------------------------

# %%
# Loop through all the cities in the list.
# We create the for loop with the enumerate() method and reference
# the index and the city in the list.
# cities = cities[1:150]
for i, city in enumerate(cities):

    #In the conditional statement, we check if the remainder of the
    # index divided by 50 is equal to 0 and if the index is greater
    # than or equal to 50. If the statement is true, then the 
    # set_count and the record_count are incremented by 1.
    # Group cities in sets of 50 for logging purposes.
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 1
        time.sleep(60)
    # Inside the conditional statement, we create the URL endpoint 
    # for each city, as before. However, we are removing the blank 
    # spaces in the city name and concatenating the city name with,
    # city.replace(" ","+"). This will find the corresponding 
    # weather data for the city instead of finding the weather data 
    # for the first part of the city name.
    # Create endpoint URL with each city.
    city_url = url + "&q=" + city.replace(" ","+")
    print(city_url)
    # we add a print statement that tells us the record count and 
    # set count, and the city that is being processed.
    # Log the URL, record, and set numbers and the city.
    print(f"Processing Record {record_count} of Set {set_count} | {city}")
    
    # Add 1 to the record count, before next city.
    record_count += 1
    
# Run an API request for each of the cities.
    try:
        # Parse the JSON and retrieve data.
        city_weather = requests.get(city_url).json()
        # Parse out the needed data.
        city_lat = city_weather["coord"]["lat"]
        city_lng = city_weather["coord"]["lon"]
        city_max_temp = city_weather["main"]["temp_max"]
        city_humidity = city_weather["main"]["humidity"]
        city_clouds = city_weather["clouds"]["all"]
        city_wind = city_weather["wind"]["speed"]
        city_country = city_weather["sys"]["country"]
        city_description = city_weather["weather"][0]["description"]
        # Convert the date to ISO standard.
        city_date = datetime.utcfromtimestamp(city_weather["dt"]).strftime('%Y-%m-%d %H:%M:%S')
        # Append the city information into city_data list.
        city_data.append({"City": city.title(),
                          "Lat": city_lat,
                          "Lng": city_lng,
                          "Max Temp": city_max_temp,
                          "Humidity": city_humidity,
                          "Cloudiness": city_clouds,
                          "Wind Speed": city_wind,
                          "Country": city_country,
                          "Current Description": city_description})

# If an error is experienced, skip the city.
    except:
        print("City not found. Skipping...")
        pass

# Indicate that Data Loading is complete.
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tangwani
# Processing Record 1 of Set 1 | tangwani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=hermanus
# Processing Record 2 of Set 1 | hermanus
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tuatapere
# Processing Record 3 of Set 1 | tuatapere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mataura
# Processing Record 4 of Set 1 | mataura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bethel
# Processing Record 5 of Set 1 | bethel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=yellowknife
# Processing Record 6 of Set 1 | yellowknife
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=amderma
# Processing Record 7 of Set 1 | amderma
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=lasa
# Processing Record 8 of Set 1 | lasa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=guelengdeng
# Processing Record 9 of Set 1 | guelengdeng
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=punta+arenas
# Processing Record 10 of Set 1 | punta arenas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=rikitea
# Processing Record 11 of Set 1 | rikitea
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=louisbourg
# Processing Record 12 of Set 1 | louisbourg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=puerto+ayora
# Processing Record 13 of Set 1 | puerto ayora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tsihombe
# Processing Record 14 of Set 1 | tsihombe
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=atuona
# Processing Record 15 of Set 1 | atuona
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mbandaka
# Processing Record 16 of Set 1 | mbandaka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tuktoyaktuk
# Processing Record 17 of Set 1 | tuktoyaktuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=teya
# Processing Record 18 of Set 1 | teya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=puerto+penasco
# Processing Record 19 of Set 1 | puerto penasco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ventspils
# Processing Record 20 of Set 1 | ventspils
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ribeira+grande
# Processing Record 21 of Set 1 | ribeira grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=vaini
# Processing Record 22 of Set 1 | vaini
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bluff
# Processing Record 23 of Set 1 | bluff
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sibu
# Processing Record 24 of Set 1 | sibu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=pinawa
# Processing Record 25 of Set 1 | pinawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=barentsburg
# Processing Record 26 of Set 1 | barentsburg
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dubbo
# Processing Record 27 of Set 1 | dubbo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kavieng
# Processing Record 28 of Set 1 | kavieng
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=cheremukhovo
# Processing Record 29 of Set 1 | cheremukhovo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=hilo
# Processing Record 30 of Set 1 | hilo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=castro
# Processing Record 31 of Set 1 | castro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ust-kuyga
# Processing Record 32 of Set 1 | ust-kuyga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sola
# Processing Record 33 of Set 1 | sola
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=skalistyy
# Processing Record 34 of Set 1 | skalistyy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=praia
# Processing Record 35 of Set 1 | praia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ahipara
# Processing Record 36 of Set 1 | ahipara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=migori
# Processing Record 37 of Set 1 | migori
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=henties+bay
# Processing Record 38 of Set 1 | henties bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=charters+towers
# Processing Record 39 of Set 1 | charters towers
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ushuaia
# Processing Record 40 of Set 1 | ushuaia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=arraial+do+cabo
# Processing Record 41 of Set 1 | arraial do cabo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=camocim
# Processing Record 42 of Set 1 | camocim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=severo-kurilsk
# Processing Record 43 of Set 1 | severo-kurilsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=illoqqortoormiut
# Processing Record 44 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mareeba
# Processing Record 45 of Set 1 | mareeba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=qaanaaq
# Processing Record 46 of Set 1 | qaanaaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=chapais
# Processing Record 47 of Set 1 | chapais
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=feijo
# Processing Record 48 of Set 1 | feijo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=busselton
# Processing Record 49 of Set 1 | busselton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=saldanha
# Processing Record 50 of Set 1 | saldanha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=beyneu
# Processing Record 1 of Set 2 | beyneu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=cabo+san+lucas
# Processing Record 2 of Set 2 | cabo san lucas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ponta+do+sol
# Processing Record 3 of Set 2 | ponta do sol
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=muros
# Processing Record 4 of Set 2 | muros
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=san+patricio
# Processing Record 5 of Set 2 | san patricio
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=port+hardy
# Processing Record 6 of Set 2 | port hardy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=scarborough
# Processing Record 7 of Set 2 | scarborough
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dwarka
# Processing Record 8 of Set 2 | dwarka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=monrovia
# Processing Record 9 of Set 2 | monrovia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=grindavik
# Processing Record 10 of Set 2 | grindavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=iqaluit
# Processing Record 11 of Set 2 | iqaluit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=saint-louis
# Processing Record 12 of Set 2 | saint-louis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tulskiy
# Processing Record 13 of Set 2 | tulskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=vaitape
# Processing Record 14 of Set 2 | vaitape
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kongoussi
# Processing Record 15 of Set 2 | kongoussi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tiksi
# Processing Record 16 of Set 2 | tiksi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=butaritari
# Processing Record 17 of Set 2 | butaritari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=hofn
# Processing Record 18 of Set 2 | hofn
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=georgetown
# Processing Record 19 of Set 2 | georgetown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=praia+da+vitoria
# Processing Record 20 of Set 2 | praia da vitoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=coahuayana
# Processing Record 21 of Set 2 | coahuayana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=barrow
# Processing Record 22 of Set 2 | barrow
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=norman+wells
# Processing Record 23 of Set 2 | norman wells
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=cabra
# Processing Record 24 of Set 2 | cabra
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=pevek
# Processing Record 25 of Set 2 | pevek
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=karkaralinsk
# Processing Record 26 of Set 2 | karkaralinsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ambon
# Processing Record 27 of Set 2 | ambon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=east+london
# Processing Record 28 of Set 2 | east london
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tasiilaq
# Processing Record 29 of Set 2 | tasiilaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=egvekinot
# Processing Record 30 of Set 2 | egvekinot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=khasan
# Processing Record 31 of Set 2 | khasan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=pangody
# Processing Record 32 of Set 2 | pangody
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=katsuura
# Processing Record 33 of Set 2 | katsuura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kushmurun
# Processing Record 34 of Set 2 | kushmurun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=port+alfred
# Processing Record 35 of Set 2 | port alfred
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=chuy
# Processing Record 36 of Set 2 | chuy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=la+ronge
# Processing Record 37 of Set 2 | la ronge
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ashland
# Processing Record 38 of Set 2 | ashland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=la+libertad
# Processing Record 39 of Set 2 | la libertad
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kanniyakumari
# Processing Record 40 of Set 2 | kanniyakumari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=cidreira
# Processing Record 41 of Set 2 | cidreira
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=longyearbyen
# Processing Record 42 of Set 2 | longyearbyen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sabang
# Processing Record 43 of Set 2 | sabang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bredasdorp
# Processing Record 44 of Set 2 | bredasdorp
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=khani
# Processing Record 45 of Set 2 | khani
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=wahran
# Processing Record 46 of Set 2 | wahran
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=faya
# Processing Record 47 of Set 2 | faya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=taolanaro
# Processing Record 48 of Set 2 | taolanaro
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=severo-yeniseyskiy
# Processing Record 49 of Set 2 | severo-yeniseyskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=albany
# Processing Record 50 of Set 2 | albany
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mackay
# Processing Record 1 of Set 3 | mackay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ercis
# Processing Record 2 of Set 3 | ercis
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=constitucion
# Processing Record 3 of Set 3 | constitucion
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kenai
# Processing Record 4 of Set 3 | kenai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kloulklubed
# Processing Record 5 of Set 3 | kloulklubed
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=saint-philippe
# Processing Record 6 of Set 3 | saint-philippe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=shinjo
# Processing Record 7 of Set 3 | shinjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tamale
# Processing Record 8 of Set 3 | tamale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=fortuna
# Processing Record 9 of Set 3 | fortuna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=carnarvon
# Processing Record 10 of Set 3 | carnarvon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=taseyevo
# Processing Record 11 of Set 3 | taseyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ciudad+bolivar
# Processing Record 12 of Set 3 | ciudad bolivar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ca+mau
# Processing Record 13 of Set 3 | ca mau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=jamestown
# Processing Record 14 of Set 3 | jamestown
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kapaa
# Processing Record 15 of Set 3 | kapaa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=matehuala
# Processing Record 16 of Set 3 | matehuala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=one+hundred+mile+house
# Processing Record 17 of Set 3 | one hundred mile house
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tuy+hoa
# Processing Record 18 of Set 3 | tuy hoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=katherine
# Processing Record 19 of Set 3 | katherine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kodiak
# Processing Record 20 of Set 3 | kodiak
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=balkhash
# Processing Record 21 of Set 3 | balkhash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ilulissat
# Processing Record 22 of Set 3 | ilulissat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=chokurdakh
# Processing Record 23 of Set 3 | chokurdakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bere
# Processing Record 24 of Set 3 | bere
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=lodja
# Processing Record 25 of Set 3 | lodja
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=grand+river+south+east
# Processing Record 26 of Set 3 | grand river south east
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=puerto+carreno
# Processing Record 27 of Set 3 | puerto carreno
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=viedma
# Processing Record 28 of Set 3 | viedma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=belushya+guba
# Processing Record 29 of Set 3 | belushya guba
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ossora
# Processing Record 30 of Set 3 | ossora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=pisco
# Processing Record 31 of Set 3 | pisco
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=thompson
# Processing Record 32 of Set 3 | thompson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dallas
# Processing Record 33 of Set 3 | dallas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dikson
# Processing Record 34 of Set 3 | dikson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=phan+thiet
# Processing Record 35 of Set 3 | phan thiet
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=te+anau
# Processing Record 36 of Set 3 | te anau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=avarua
# Processing Record 37 of Set 3 | avarua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=port+elizabeth
# Processing Record 38 of Set 3 | port elizabeth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kaele
# Processing Record 39 of Set 3 | kaele
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=wattegama
# Processing Record 40 of Set 3 | wattegama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=lavrentiya
# Processing Record 41 of Set 3 | lavrentiya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=locri
# Processing Record 42 of Set 3 | locri
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=khatanga
# Processing Record 43 of Set 3 | khatanga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=biograd+na+moru
# Processing Record 44 of Set 3 | biograd na moru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mankera
# Processing Record 45 of Set 3 | mankera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=okato
# Processing Record 46 of Set 3 | okato
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=suntar
# Processing Record 47 of Set 3 | suntar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=warrnambool
# Processing Record 48 of Set 3 | warrnambool
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bathsheba
# Processing Record 49 of Set 3 | bathsheba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=vylgort
# Processing Record 50 of Set 3 | vylgort
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dingle
# Processing Record 1 of Set 4 | dingle
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=erzin
# Processing Record 2 of Set 4 | erzin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=nizhneyansk
# Processing Record 3 of Set 4 | nizhneyansk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=berlevag
# Processing Record 4 of Set 4 | berlevag
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=hobart
# Processing Record 5 of Set 4 | hobart
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=urengoy
# Processing Record 6 of Set 4 | urengoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=yongan
# Processing Record 7 of Set 4 | yongan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=vila+franca+do+campo
# Processing Record 8 of Set 4 | vila franca do campo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kaitangata
# Processing Record 9 of Set 4 | kaitangata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=turukhansk
# Processing Record 10 of Set 4 | turukhansk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=cape+town
# Processing Record 11 of Set 4 | cape town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=rochegda
# Processing Record 12 of Set 4 | rochegda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=vaitupu
# Processing Record 13 of Set 4 | vaitupu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kaeo
# Processing Record 14 of Set 4 | kaeo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=samusu
# Processing Record 15 of Set 4 | samusu
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=lagoa
# Processing Record 16 of Set 4 | lagoa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=manado
# Processing Record 17 of Set 4 | manado
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=victoria
# Processing Record 18 of Set 4 | victoria
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=vestmannaeyjar
# Processing Record 19 of Set 4 | vestmannaeyjar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=half+moon+bay
# Processing Record 20 of Set 4 | half moon bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=isangel
# Processing Record 21 of Set 4 | isangel
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=raga
# Processing Record 22 of Set 4 | raga
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=carauari
# Processing Record 23 of Set 4 | carauari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=laguna
# Processing Record 24 of Set 4 | laguna
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=chabahar
# Processing Record 25 of Set 4 | chabahar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=okha
# Processing Record 26 of Set 4 | okha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ostrovnoy
# Processing Record 27 of Set 4 | ostrovnoy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=trento
# Processing Record 28 of Set 4 | trento
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=warqla
# Processing Record 29 of Set 4 | warqla
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=lebu
# Processing Record 30 of Set 4 | lebu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=nago
# Processing Record 31 of Set 4 | nago
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tura
# Processing Record 32 of Set 4 | tura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=narsaq
# Processing Record 33 of Set 4 | narsaq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=faanui
# Processing Record 34 of Set 4 | faanui
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sabaudia
# Processing Record 35 of Set 4 | sabaudia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=nikolskoye
# Processing Record 36 of Set 4 | nikolskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=volsk
# Processing Record 37 of Set 4 | volsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=hasaki
# Processing Record 38 of Set 4 | hasaki
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mar+del+plata
# Processing Record 39 of Set 4 | mar del plata
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=alofi
# Processing Record 40 of Set 4 | alofi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=saskylakh
# Processing Record 41 of Set 4 | saskylakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bengkulu
# Processing Record 42 of Set 4 | bengkulu
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=upernavik
# Processing Record 43 of Set 4 | upernavik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=leningradskiy
# Processing Record 44 of Set 4 | leningradskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=caravelas
# Processing Record 45 of Set 4 | caravelas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kimbe
# Processing Record 46 of Set 4 | kimbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=winnemucca
# Processing Record 47 of Set 4 | winnemucca
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dukat
# Processing Record 48 of Set 4 | dukat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dicabisagan
# Processing Record 49 of Set 4 | dicabisagan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=denpasar
# Processing Record 50 of Set 4 | denpasar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=saint+george
# Processing Record 1 of Set 5 | saint george
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sumbe
# Processing Record 2 of Set 5 | sumbe
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bambous+virieux
# Processing Record 3 of Set 5 | bambous virieux
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kahului
# Processing Record 4 of Set 5 | kahului
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=chapleau
# Processing Record 5 of Set 5 | chapleau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=port+lincoln
# Processing Record 6 of Set 5 | port lincoln
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=natitingou
# Processing Record 7 of Set 5 | natitingou
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=manavalakurichi
# Processing Record 8 of Set 5 | manavalakurichi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=airai
# Processing Record 9 of Set 5 | airai
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=axim
# Processing Record 10 of Set 5 | axim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=maneadero
# Processing Record 11 of Set 5 | maneadero
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sobolevo
# Processing Record 12 of Set 5 | sobolevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=comodoro+rivadavia
# Processing Record 13 of Set 5 | comodoro rivadavia
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=komsomolskiy
# Processing Record 14 of Set 5 | komsomolskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=portland
# Processing Record 15 of Set 5 | portland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=manta
# Processing Record 16 of Set 5 | manta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=teknaf
# Processing Record 17 of Set 5 | teknaf
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bandarbeyla
# Processing Record 18 of Set 5 | bandarbeyla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=lorengau
# Processing Record 19 of Set 5 | lorengau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=aquiraz
# Processing Record 20 of Set 5 | aquiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tonj
# Processing Record 21 of Set 5 | tonj
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=chunskiy
# Processing Record 22 of Set 5 | chunskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=cockburn+town
# Processing Record 23 of Set 5 | cockburn town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sentyabrskiy
# Processing Record 24 of Set 5 | sentyabrskiy
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=gat
# Processing Record 25 of Set 5 | gat
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=zorleni
# Processing Record 26 of Set 5 | zorleni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=nargana
# Processing Record 27 of Set 5 | nargana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mogadouro
# Processing Record 28 of Set 5 | mogadouro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=talnakh
# Processing Record 29 of Set 5 | talnakh
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kabalo
# Processing Record 30 of Set 5 | kabalo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=olafsvik
# Processing Record 31 of Set 5 | olafsvik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=hithadhoo
# Processing Record 32 of Set 5 | hithadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=perth
# Processing Record 33 of Set 5 | perth
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=charyshskoye
# Processing Record 34 of Set 5 | charyshskoye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kuytun
# Processing Record 35 of Set 5 | kuytun
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=lolua
# Processing Record 36 of Set 5 | lolua
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=karratha
# Processing Record 37 of Set 5 | karratha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mahebourg
# Processing Record 38 of Set 5 | mahebourg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=wukari
# Processing Record 39 of Set 5 | wukari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ancud
# Processing Record 40 of Set 5 | ancud
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=maua
# Processing Record 41 of Set 5 | maua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=asau
# Processing Record 42 of Set 5 | asau
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=iranshahr
# Processing Record 43 of Set 5 | iranshahr
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ponta+delgada
# Processing Record 44 of Set 5 | ponta delgada
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kavaratti
# Processing Record 45 of Set 5 | kavaratti
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=provideniya
# Processing Record 46 of Set 5 | provideniya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=masterton
# Processing Record 47 of Set 5 | masterton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=nador
# Processing Record 48 of Set 5 | nador
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=halalo
# Processing Record 49 of Set 5 | halalo
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mys+shmidta
# Processing Record 50 of Set 5 | mys shmidta
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sredec
# Processing Record 1 of Set 6 | sredec
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=baherden
# Processing Record 2 of Set 6 | baherden
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=santa+cruz
# Processing Record 3 of Set 6 | santa cruz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=neuquen
# Processing Record 4 of Set 6 | neuquen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=betsiamites
# Processing Record 5 of Set 6 | betsiamites
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=burnie
# Processing Record 6 of Set 6 | burnie
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sawtell
# Processing Record 7 of Set 6 | sawtell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=hay+river
# Processing Record 8 of Set 6 | hay river
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=katsina
# Processing Record 9 of Set 6 | katsina
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=torbay
# Processing Record 10 of Set 6 | torbay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=coihaique
# Processing Record 11 of Set 6 | coihaique
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tabas
# Processing Record 12 of Set 6 | tabas
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=camacha
# Processing Record 13 of Set 6 | camacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=nishihara
# Processing Record 14 of Set 6 | nishihara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=seddon
# Processing Record 15 of Set 6 | seddon
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=thinadhoo
# Processing Record 16 of Set 6 | thinadhoo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bowen
# Processing Record 17 of Set 6 | bowen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dunedin
# Processing Record 18 of Set 6 | dunedin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=broken+hill
# Processing Record 19 of Set 6 | broken hill
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=yaan
# Processing Record 20 of Set 6 | yaan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bambanglipuro
# Processing Record 21 of Set 6 | bambanglipuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tsienyane
# Processing Record 22 of Set 6 | tsienyane
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=morehead
# Processing Record 23 of Set 6 | morehead
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=azangaro
# Processing Record 24 of Set 6 | azangaro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mogwase
# Processing Record 25 of Set 6 | mogwase
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=almaznyy
# Processing Record 26 of Set 6 | almaznyy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=pyaozerskiy
# Processing Record 27 of Set 6 | pyaozerskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=yar-sale
# Processing Record 28 of Set 6 | yar-sale
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ampanihy
# Processing Record 29 of Set 6 | ampanihy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=khudumelapye
# Processing Record 30 of Set 6 | khudumelapye
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=west+wendover
# Processing Record 31 of Set 6 | west wendover
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=new+norfolk
# Processing Record 32 of Set 6 | new norfolk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dekar
# Processing Record 33 of Set 6 | dekar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=hervey+bay
# Processing Record 34 of Set 6 | hervey bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dzhebariki-khaya
# Processing Record 35 of Set 6 | dzhebariki-khaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=maba
# Processing Record 36 of Set 6 | maba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=port+hedland
# Processing Record 37 of Set 6 | port hedland
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=codrington
# Processing Record 38 of Set 6 | codrington
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=charagua
# Processing Record 39 of Set 6 | charagua
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=palana
# Processing Record 40 of Set 6 | palana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mana
# Processing Record 41 of Set 6 | mana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=wachtebeke
# Processing Record 42 of Set 6 | wachtebeke
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=geraldton
# Processing Record 43 of Set 6 | geraldton
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=glace+bay
# Processing Record 44 of Set 6 | glace bay
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kuzedeyevo
# Processing Record 45 of Set 6 | kuzedeyevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=porto+belo
# Processing Record 46 of Set 6 | porto belo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=palmer
# Processing Record 47 of Set 6 | palmer
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kampot
# Processing Record 48 of Set 6 | kampot
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=okhotsk
# Processing Record 49 of Set 6 | okhotsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=saint-georges
# Processing Record 50 of Set 6 | saint-georges
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=lindi
# Processing Record 1 of Set 7 | lindi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=honiara
# Processing Record 2 of Set 7 | honiara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=juarez
# Processing Record 3 of Set 7 | juarez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=gushikawa
# Processing Record 4 of Set 7 | gushikawa
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=naze
# Processing Record 5 of Set 7 | naze
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=natchez
# Processing Record 6 of Set 7 | natchez
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=iquitos
# Processing Record 7 of Set 7 | iquitos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=santo+domingo
# Processing Record 8 of Set 7 | santo domingo
# ...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tala
# Processing Record 41 of Set 13 | tala
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=cayenne
# Processing Record 42 of Set 13 | cayenne
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dauphin
# Processing Record 43 of Set 13 | dauphin
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=clarence+town
# Processing Record 44 of Set 13 | clarence town
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kurikka
# Processing Record 45 of Set 13 | kurikka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tottori
# Processing Record 46 of Set 13 | tottori
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tazovskiy
# Processing Record 47 of Set 13 | tazovskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mweka
# Processing Record 48 of Set 13 | mweka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=salalah
# Processing Record 49 of Set 13 | salalah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=biltine
# Processing Record 50 of Set 13 | biltine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=umm+kaddadah
# Processing Record 1 of Set 14 | umm kaddadah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=guia+de+isora
# Processing Record 2 of Set 14 | guia de isora
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=yartsevo
# Processing Record 3 of Set 14 | yartsevo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=raudeberg
# Processing Record 4 of Set 14 | raudeberg
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=buraydah
# Processing Record 5 of Set 14 | buraydah
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ambodifototra
# Processing Record 6 of Set 14 | ambodifototra
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=pontes+e+lacerda
# Processing Record 7 of Set 14 | pontes e lacerda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=camabatela
# Processing Record 8 of Set 14 | camabatela
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sechura
# Processing Record 9 of Set 14 | sechura
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=pundaguitan
# Processing Record 10 of Set 14 | pundaguitan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=avanigadda
# Processing Record 11 of Set 14 | avanigadda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=maloyaroslavets
# Processing Record 12 of Set 14 | maloyaroslavets
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=baijiantan
# Processing Record 13 of Set 14 | baijiantan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=baykit
# Processing Record 14 of Set 14 | baykit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=zyryanka
# Processing Record 15 of Set 14 | zyryanka
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=wesley
# Processing Record 16 of Set 14 | wesley
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=wamba
# Processing Record 17 of Set 14 | wamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=manokwari
# Processing Record 18 of Set 14 | manokwari
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=riohacha
# Processing Record 19 of Set 14 | riohacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=valley+city
# Processing Record 20 of Set 14 | valley city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=llangefni
# Processing Record 21 of Set 14 | llangefni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tiznit
# Processing Record 22 of Set 14 | tiznit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sinnamary
# Processing Record 23 of Set 14 | sinnamary
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=eskasem
# Processing Record 24 of Set 14 | eskasem
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=rio+grande
# Processing Record 25 of Set 14 | rio grande
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=vanavara
# Processing Record 26 of Set 14 | vanavara
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=nemuro
# Processing Record 27 of Set 14 | nemuro
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=reconquista
# Processing Record 28 of Set 14 | reconquista
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mandalgovi
# Processing Record 29 of Set 14 | mandalgovi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=san+cristobal
# Processing Record 30 of Set 14 | san cristobal
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=yakeshi
# Processing Record 31 of Set 14 | yakeshi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=camopi
# Processing Record 32 of Set 14 | camopi
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=mustla
# Processing Record 33 of Set 14 | mustla
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bukachacha
# Processing Record 34 of Set 14 | bukachacha
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=aleppo
# Processing Record 35 of Set 14 | aleppo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=shiraz
# Processing Record 36 of Set 14 | shiraz
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=palafrugell
# Processing Record 37 of Set 14 | palafrugell
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=pilar
# Processing Record 38 of Set 14 | pilar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tupik
# Processing Record 39 of Set 14 | tupik
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ha
# Processing Record 40 of Set 14 | ha
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=willmar
# Processing Record 41 of Set 14 | willmar
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kuche
# Processing Record 42 of Set 14 | kuche
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=samana
# Processing Record 43 of Set 14 | samana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=constantine
# Processing Record 44 of Set 14 | constantine
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=vostok
# Processing Record 45 of Set 14 | vostok
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=yerbogachen
# Processing Record 46 of Set 14 | yerbogachen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sokoni
# Processing Record 47 of Set 14 | sokoni
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=biritiba-mirim
# Processing Record 48 of Set 14 | biritiba-mirim
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=el+naranjo
# Processing Record 49 of Set 14 | el naranjo
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ivanava
# Processing Record 50 of Set 14 | ivanava
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=gamba
# Processing Record 1 of Set 15 | gamba
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=makakilo+city
# Processing Record 2 of Set 15 | makakilo city
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ust-tsilma
# Processing Record 3 of Set 15 | ust-tsilma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=alyangula
# Processing Record 4 of Set 15 | alyangula
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=olovyannaya
# Processing Record 5 of Set 15 | olovyannaya
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=chicama
# Processing Record 6 of Set 15 | chicama
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=santa+cruz+de+la+palma
# Processing Record 7 of Set 15 | santa cruz de la palma
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=buchanan
# Processing Record 8 of Set 15 | buchanan
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=chaoyang
# Processing Record 9 of Set 15 | chaoyang
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=toliary
# Processing Record 10 of Set 15 | toliary
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=palenque
# Processing Record 11 of Set 15 | palenque
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=nantucket
# Processing Record 12 of Set 15 | nantucket
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=tatarsk
# Processing Record 13 of Set 15 | tatarsk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=wexford
# Processing Record 14 of Set 15 | wexford
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=san+rafael+del+sur
# Processing Record 15 of Set 15 | san rafael del sur
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=sampit
# Processing Record 16 of Set 15 | sampit
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=primorskiy
# Processing Record 17 of Set 15 | primorskiy
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=campo+de+criptana
# Processing Record 18 of Set 15 | campo de criptana
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=nuuk
# Processing Record 19 of Set 15 | nuuk
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=xining
# Processing Record 20 of Set 15 | xining
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bafq
# Processing Record 21 of Set 15 | bafq
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=rawson
# Processing Record 22 of Set 15 | rawson
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ijaki
# Processing Record 23 of Set 15 | ijaki
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=port+blair
# Processing Record 24 of Set 15 | port blair
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=changji
# Processing Record 25 of Set 15 | changji
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=datong
# Processing Record 26 of Set 15 | datong
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=caconda
# Processing Record 27 of Set 15 | caconda
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kazalinsk
# Processing Record 28 of Set 15 | kazalinsk
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=montes+altos
# Processing Record 29 of Set 15 | montes altos
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ostersund
# Processing Record 30 of Set 15 | ostersund
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=itubera
# Processing Record 31 of Set 15 | itubera
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=ugoofaaru
# Processing Record 32 of Set 15 | ugoofaaru
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=vila
# Processing Record 33 of Set 15 | vila
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=jiroft
# Processing Record 34 of Set 15 | jiroft
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bolungarvik
# Processing Record 35 of Set 15 | bolungarvik
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=khash
# Processing Record 36 of Set 15 | khash
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=dongying
# Processing Record 37 of Set 15 | dongying
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=yumen
# Processing Record 38 of Set 15 | yumen
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=salta
# Processing Record 39 of Set 15 | salta
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=kasra
# Processing Record 40 of Set 15 | kasra
# City not found. Skipping...
# http://api.openweathermap.org/data/2.5/weather?units=Imperial&APPID=ce2012e135fc0628b035a9f99c3fd381&q=bouafle
# Processing Record 41 of Set 15 | bouafle
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the array of dictionaries to a Pandas DataFrame.
city_data_df = pd.DataFrame(city_data)
city_data_df.head(10)
# Out:
#            City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0      Tangwani  28.2787   68.9972     53.53        38          79
# 1      Hermanus -34.4187   19.2345     63.90        93          91
# 2     Tuatapere -46.1333  167.6833     59.83        45           0
# 3       Mataura -46.1927  168.8643     59.49        36          21
# 4        Bethel  41.3712  -73.4140     27.64        75           0
# 5   Yellowknife  62.4560 -114.3525     -1.68        84          75
# 6          Lasa  46.6166   10.7002     44.06        86         100
# 7  Punta Arenas -53.1500  -70.9167     51.91        87          75
# 8       Rikitea -23.1203 -134.9692     79.00        71          45
# 9  Puerto Ayora  -0.7393  -90.3518     73.54        92          15
#
#    Wind Speed Country Current Description
# 0       11.99      PK       broken clouds
# 1        3.22      ZA     overcast clouds
# 2        6.82      NZ           clear sky
# 3        1.88      NZ          few clouds
# 4        3.44      US           clear sky
# 5        4.61      CA          light snow
# 6        5.79      IT          light snow
# 7        6.91      CL       broken clouds
# 8       19.26      PF    scattered clouds
# 9        3.00      EC          few clouds

# %%
# Reorder the columns in the order you want them to appear.    
new_column_order =["City", "Country", "Lat", "Lng", "Max Temp","Humidity", "Cloudiness", "Wind Speed", "Current Description"]
city_data_df = city_data_df[new_column_order]
city_data_df
# Out:
#           City Country      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# 0     Tangwani      PK  28.2787   68.9972     53.53        38          79
# 1     Hermanus      ZA -34.4187   19.2345     63.90        93          91
# 2    Tuatapere      NZ -46.1333  167.6833     59.83        45           0
# 3      Mataura      NZ -46.1927  168.8643     59.49        36          21
# 4       Bethel      US  41.3712  -73.4140     27.64        75           0
# ..         ...     ...      ...       ...       ...       ...         ...
# 673      Khash      IR  28.2211   61.2158     45.27        36           6
# 674   Dongying      CN  37.4564  118.4856     34.77        29         100
# 675      Yumen      CN  40.2833   97.2000     13.39        70         100
# 676      Salta      AR -24.7859  -65.4117     59.59        90          75
# 677    Bouafle      CI   6.9904   -5.7442     78.82        83          96
#
#      Wind Speed Current Description
# 0         11.99       broken clouds
# 1          3.22     overcast clouds
# 2          6.82           clear sky
# 3          1.88          few clouds
# 4          3.44           clear sky
# ..          ...                 ...
# 673        6.87           clear sky
# 674        2.77     overcast clouds
# 675       10.85     overcast clouds
# 676        1.99       broken clouds
# 677        2.91     overcast clouds
#
# [678 rows x 9 columns]

# %%
# Create the output file (CSV).
output_data_file = "WeatherPy_database.csv"
# Export the City_Data into a CSV.
city_data_df.to_csv(output_data_file, index_label="City_ID")
